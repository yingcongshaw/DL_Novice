# %% [markdown]
# ### 1.faster_rcnn_r50_fpn_1x_didi; max_epochs=20

# %%
# !python mmdetection/tools/train.py mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_didi.py  \
    --cfg-options model.roi_head.bbox_head.num_classes=12 runner.max_epochs=20
# Out:
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 记录mAG
exec_result = pd.DataFrame(columns=['epoch', 'mAP'])
exec_result.loc[exec_result.shape[0]] = ['1', 0.166]
exec_result.loc[exec_result.shape[0]] = ['2', 0.197]
exec_result.loc[exec_result.shape[0]] = ['3', 0.203]
exec_result.loc[exec_result.shape[0]] = ['4', 0.219]
exec_result.loc[exec_result.shape[0]] = ['5', 0.234]
exec_result.loc[exec_result.shape[0]] = ['6', 0.226]
exec_result.loc[exec_result.shape[0]] = ['7', 0.206]
exec_result.loc[exec_result.shape[0]] = ['8', 0.228]
exec_result.loc[exec_result.shape[0]] = ['9', 0.278]
exec_result.loc[exec_result.shape[0]] = ['10', 0.28]
exec_result.loc[exec_result.shape[0]] = ['11', 0.281]
exec_result.loc[exec_result.shape[0]] = ['12', 0.285]
exec_result.loc[exec_result.shape[0]] = ['13', 0.285]
exec_result.loc[exec_result.shape[0]] = ['14', 0.284]
exec_result.loc[exec_result.shape[0]] = ['15', 0.283]
exec_result.loc[exec_result.shape[0]] = ['16', 0.282]
exec_result.loc[exec_result.shape[0]] = ['17', 0.282]
exec_result.loc[exec_result.shape[0]] = ['18', 0.28]
exec_result.loc[exec_result.shape[0]] = ['19', 0.277]
exec_result.loc[exec_result.shape[0]] = ['20', 0.282]


plt.figure(figsize=(10,6), dpi=100)
plt.rcParams['font.sans-serif']=['SimHei']
plt.plot(exec_result['epoch'], exec_result['mAP'].to_list(), marker='s', label ='faster_rcnn_r50_fpn_1x')
plt.xlabel('epoch', fontsize=16)
plt.xticks(range(0,20), fontsize=12)
plt.ylabel('mAP', fontsize=16)
plt.yticks(np.arange(150,300,10)/1000,fontsize=12)
plt.legend()
plt.show()

# %%
np.arange(150,300,10)/1000
# Out:
# array([0.15, 0.16, 0.17, 0.18, 0.19, 0.2 , 0.21, 0.22, 0.23, 0.24, 0.25,
#        0.26, 0.27, 0.28, 0.29])
