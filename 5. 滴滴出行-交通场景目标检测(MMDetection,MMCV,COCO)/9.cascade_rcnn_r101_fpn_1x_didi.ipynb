# %% [markdown]
# ### cascade_rcnn_r101_fpn_1x_didi

# %%
import glob
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 默认

# %%
# !python mmdetection/tools/train.py mmdetection/configs/cascade_rcnn/cascade_rcnn_r101_fpn_1x_didi.py
# Out:
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2023-02-01 09:31:12,263 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.9.15 (main, Nov 24 2022, 14:31:59) [GCC 11.2.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3070
# CUDA_HOME: /usr/local/cuda-11.7
# NVCC: Cuda compilation tools, release 11.7, V11.7.99
# GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04) 11.3.0
# PyTorch: 1.13.1+cu117-with-pypi-cudnn
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.14.1+cu117
# OpenCV: 4.7.0
# MMCV: 1.7.1
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.7
# MMDetection: 2.27.0+unknown
# ------------------------------------------------------------
#
# 2023-02-01 09:31:12,759 - mmdet - INFO - Distributed training: False
# 2023-02-01 09:31:13,199 - mmdet - INFO - Config:
# model = dict(
#     type='CascadeRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=101,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained',
#                       checkpoint='torchvision://resnet101')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(
#             type='SmoothL1Loss', beta=0.1111111111111111, loss_weight=1.0)),
#     roi_head=dict(
#         type='CascadeRoIHead',
#         num_stages=3,
#         stage_loss_weights=[1, 0.5, 0.25],
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=[
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.1, 0.1, 0.2, 0.2]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.05, 0.05, 0.1, 0.1]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.033, 0.033, 0.067, 0.067]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0))
#         ]),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=0,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=2000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.5,
#                     neg_iou_thr=0.5,
#                     min_pos_iou=0.5,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.6,
#                     neg_iou_thr=0.6,
#                     min_pos_iou=0.6,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.7,
#                     neg_iou_thr=0.7,
#                     min_pos_iou=0.7,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False)
#         ]),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = '/home/shaw/work/DL/hw5/mmdetection/dataset_release/'
# classes = ('car', 'van', 'bus', 'truck', 'person', 'bicycle', 'motorcycle',
#            'open-tricycle', 'closed-tricycle', 'forklift', 'large-block',
#            'small-block')
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file=
#         '/home/shaw/work/DL/hw5/mmdetection/dataset_release/train.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/train/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file='/home/shaw/work/DL/hw5/mmdetection/dataset_release/val.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/val/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file='/home/shaw/work/DL/hw5/mmdetection/dataset_release/test.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/test/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=20)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=8)
# work_dir = './work_dirs/cascade_rcnn_r101_fpn_1x_didi'
# auto_resume = False
# gpu_ids = [0]
#
# 2023-02-01 09:31:13,200 - mmdet - INFO - Set random seed to 1884014457, deterministic: False
# 2023-02-01 09:31:13,658 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet101'}
# 2023-02-01 09:31:13,658 - mmcv - INFO - load model from: torchvision://resnet101
# 2023-02-01 09:31:13,659 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet101
# 2023-02-01 09:31:13,764 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2023-02-01 09:31:13,788 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2023-02-01 09:31:13,804 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2023-02-01 09:31:13,807 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-01 09:31:13,871 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-01 09:31:13,935 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,009 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,010 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,011 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,012 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.6.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.7.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.8.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,013 - mmcv - INFO -
# backbone.layer3.9.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.9.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.9.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.10.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.11.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.12.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,014 - mmcv - INFO -
# backbone.layer3.13.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# backbone.layer3.13.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# backbone.layer3.13.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# backbone.layer3.13.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# backbone.layer3.14.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# backbone.layer3.14.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet101
#
# 2023-02-01 09:31:14,015 - mmcv - INFO -
# ...
# 2023-02-01 18:59:27,142 - mmdet - INFO - Epoch [16][2100/4937]	lr: 2.000e-04, eta: 2:40:31, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0101, loss_rpn_bbox: 0.0131, s0.loss_cls: 0.1314, s0.acc: 95.3711, s0.loss_bbox: 0.0719, s1.loss_cls: 0.0536, s1.acc: 96.2612, s1.loss_bbox: 0.0914, s2.loss_cls: 0.0281, s2.acc: 96.1678, s2.loss_bbox: 0.0670, loss: 0.4667
# 2023-02-01 18:59:47,792 - mmdet - INFO - Epoch [16][2150/4937]	lr: 2.000e-04, eta: 2:40:10, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0108, loss_rpn_bbox: 0.0097, s0.loss_cls: 0.1121, s0.acc: 96.0547, s0.loss_bbox: 0.0634, s1.loss_cls: 0.0466, s1.acc: 96.7057, s1.loss_bbox: 0.0831, s2.loss_cls: 0.0234, s2.acc: 96.7945, s2.loss_bbox: 0.0629, loss: 0.4120
# 2023-02-01 19:00:08,508 - mmdet - INFO - Epoch [16][2200/4937]	lr: 2.000e-04, eta: 2:39:48, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0154, s0.loss_cls: 0.1331, s0.acc: 95.2090, s0.loss_bbox: 0.0787, s1.loss_cls: 0.0545, s1.acc: 96.0416, s1.loss_bbox: 0.0984, s2.loss_cls: 0.0286, s2.acc: 95.7514, s2.loss_bbox: 0.0686, loss: 0.4888
# 2023-02-01 19:00:29,185 - mmdet - INFO - Epoch [16][2250/4937]	lr: 2.000e-04, eta: 2:39:27, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0077, loss_rpn_bbox: 0.0117, s0.loss_cls: 0.1071, s0.acc: 96.0918, s0.loss_bbox: 0.0671, s1.loss_cls: 0.0463, s1.acc: 96.6878, s1.loss_bbox: 0.0819, s2.loss_cls: 0.0239, s2.acc: 96.4950, s2.loss_bbox: 0.0608, loss: 0.4064
# 2023-02-01 19:00:49,886 - mmdet - INFO - Epoch [16][2300/4937]	lr: 2.000e-04, eta: 2:39:05, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0097, loss_rpn_bbox: 0.0140, s0.loss_cls: 0.1136, s0.acc: 95.8184, s0.loss_bbox: 0.0695, s1.loss_cls: 0.0480, s1.acc: 96.4780, s1.loss_bbox: 0.0849, s2.loss_cls: 0.0240, s2.acc: 96.6745, s2.loss_bbox: 0.0625, loss: 0.4261
# 2023-02-01 19:01:10,569 - mmdet - INFO - Epoch [16][2350/4937]	lr: 2.000e-04, eta: 2:38:44, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0148, loss_rpn_bbox: 0.0169, s0.loss_cls: 0.1350, s0.acc: 95.1113, s0.loss_bbox: 0.0846, s1.loss_cls: 0.0577, s1.acc: 95.7053, s1.loss_bbox: 0.1000, s2.loss_cls: 0.0304, s2.acc: 95.3318, s2.loss_bbox: 0.0715, loss: 0.5109
# 2023-02-01 19:01:31,256 - mmdet - INFO - Epoch [16][2400/4937]	lr: 2.000e-04, eta: 2:38:22, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0069, loss_rpn_bbox: 0.0111, s0.loss_cls: 0.1132, s0.acc: 95.9395, s0.loss_bbox: 0.0705, s1.loss_cls: 0.0473, s1.acc: 96.7995, s1.loss_bbox: 0.0880, s2.loss_cls: 0.0250, s2.acc: 96.7604, s2.loss_bbox: 0.0653, loss: 0.4273
# 2023-02-01 19:01:52,062 - mmdet - INFO - Epoch [16][2450/4937]	lr: 2.000e-04, eta: 2:38:01, time: 0.416, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0119, loss_rpn_bbox: 0.0144, s0.loss_cls: 0.1297, s0.acc: 95.3164, s0.loss_bbox: 0.0767, s1.loss_cls: 0.0549, s1.acc: 96.1268, s1.loss_bbox: 0.0965, s2.loss_cls: 0.0293, s2.acc: 95.5551, s2.loss_bbox: 0.0698, loss: 0.4831
# 2023-02-01 19:02:12,839 - mmdet - INFO - Epoch [16][2500/4937]	lr: 2.000e-04, eta: 2:37:39, time: 0.416, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0091, loss_rpn_bbox: 0.0120, s0.loss_cls: 0.1176, s0.acc: 95.7227, s0.loss_bbox: 0.0703, s1.loss_cls: 0.0515, s1.acc: 96.3783, s1.loss_bbox: 0.0904, s2.loss_cls: 0.0281, s2.acc: 95.9393, s2.loss_bbox: 0.0645, loss: 0.4435
# 2023-02-01 19:02:33,502 - mmdet - INFO - Epoch [16][2550/4937]	lr: 2.000e-04, eta: 2:37:18, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0134, loss_rpn_bbox: 0.0123, s0.loss_cls: 0.1238, s0.acc: 95.5156, s0.loss_bbox: 0.0714, s1.loss_cls: 0.0503, s1.acc: 96.4194, s1.loss_bbox: 0.0825, s2.loss_cls: 0.0268, s2.acc: 96.2425, s2.loss_bbox: 0.0609, loss: 0.4415
# 2023-02-01 19:02:54,153 - mmdet - INFO - Epoch [16][2600/4937]	lr: 2.000e-04, eta: 2:36:56, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0120, loss_rpn_bbox: 0.0113, s0.loss_cls: 0.1138, s0.acc: 95.9395, s0.loss_bbox: 0.0708, s1.loss_cls: 0.0477, s1.acc: 96.6239, s1.loss_bbox: 0.0877, s2.loss_cls: 0.0248, s2.acc: 96.5021, s2.loss_bbox: 0.0633, loss: 0.4315
# 2023-02-01 19:03:14,879 - mmdet - INFO - Epoch [16][2650/4937]	lr: 2.000e-04, eta: 2:36:35, time: 0.415, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0088, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1257, s0.acc: 95.5469, s0.loss_bbox: 0.0737, s1.loss_cls: 0.0537, s1.acc: 96.2299, s1.loss_bbox: 0.0922, s2.loss_cls: 0.0284, s2.acc: 95.9975, s2.loss_bbox: 0.0650, loss: 0.4600
# 2023-02-01 19:03:35,556 - mmdet - INFO - Epoch [16][2700/4937]	lr: 2.000e-04, eta: 2:36:13, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0139, loss_rpn_bbox: 0.0131, s0.loss_cls: 0.1253, s0.acc: 95.5391, s0.loss_bbox: 0.0755, s1.loss_cls: 0.0518, s1.acc: 96.4461, s1.loss_bbox: 0.0936, s2.loss_cls: 0.0282, s2.acc: 96.2098, s2.loss_bbox: 0.0631, loss: 0.4646
# 2023-02-01 19:03:56,215 - mmdet - INFO - Epoch [16][2750/4937]	lr: 2.000e-04, eta: 2:35:52, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0134, loss_rpn_bbox: 0.0133, s0.loss_cls: 0.1260, s0.acc: 95.5645, s0.loss_bbox: 0.0705, s1.loss_cls: 0.0509, s1.acc: 96.6447, s1.loss_bbox: 0.0902, s2.loss_cls: 0.0269, s2.acc: 96.3204, s2.loss_bbox: 0.0670, loss: 0.4582
# 2023-02-01 19:04:16,894 - mmdet - INFO - Epoch [16][2800/4937]	lr: 2.000e-04, eta: 2:35:30, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0080, loss_rpn_bbox: 0.0113, s0.loss_cls: 0.1127, s0.acc: 95.7969, s0.loss_bbox: 0.0714, s1.loss_cls: 0.0474, s1.acc: 96.4764, s1.loss_bbox: 0.0923, s2.loss_cls: 0.0262, s2.acc: 95.9778, s2.loss_bbox: 0.0671, loss: 0.4363
# 2023-02-01 19:04:37,583 - mmdet - INFO - Epoch [16][2850/4937]	lr: 2.000e-04, eta: 2:35:09, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0104, loss_rpn_bbox: 0.0137, s0.loss_cls: 0.1343, s0.acc: 95.3379, s0.loss_bbox: 0.0738, s1.loss_cls: 0.0537, s1.acc: 96.3703, s1.loss_bbox: 0.0895, s2.loss_cls: 0.0293, s2.acc: 95.9611, s2.loss_bbox: 0.0656, loss: 0.4704
# 2023-02-01 19:04:58,296 - mmdet - INFO - Epoch [16][2900/4937]	lr: 2.000e-04, eta: 2:34:47, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0077, loss_rpn_bbox: 0.0120, s0.loss_cls: 0.1252, s0.acc: 95.5488, s0.loss_bbox: 0.0739, s1.loss_cls: 0.0528, s1.acc: 96.3386, s1.loss_bbox: 0.0935, s2.loss_cls: 0.0289, s2.acc: 95.8772, s2.loss_bbox: 0.0672, loss: 0.4612
# 2023-02-01 19:05:18,982 - mmdet - INFO - Epoch [16][2950/4937]	lr: 2.000e-04, eta: 2:34:26, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0101, loss_rpn_bbox: 0.0128, s0.loss_cls: 0.1287, s0.acc: 95.5703, s0.loss_bbox: 0.0722, s1.loss_cls: 0.0531, s1.acc: 96.3021, s1.loss_bbox: 0.0916, s2.loss_cls: 0.0274, s2.acc: 95.9692, s2.loss_bbox: 0.0694, loss: 0.4653
# 2023-02-01 19:05:39,670 - mmdet - INFO - Epoch [16][3000/4937]	lr: 2.000e-04, eta: 2:34:04, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0078, loss_rpn_bbox: 0.0098, s0.loss_cls: 0.1085, s0.acc: 96.3027, s0.loss_bbox: 0.0603, s1.loss_cls: 0.0433, s1.acc: 97.1412, s1.loss_bbox: 0.0765, s2.loss_cls: 0.0224, s2.acc: 96.9039, s2.loss_bbox: 0.0583, loss: 0.3869
# 2023-02-01 19:06:00,353 - mmdet - INFO - Epoch [16][3050/4937]	lr: 2.000e-04, eta: 2:33:43, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0104, loss_rpn_bbox: 0.0113, s0.loss_cls: 0.1327, s0.acc: 95.3574, s0.loss_bbox: 0.0703, s1.loss_cls: 0.0547, s1.acc: 96.1490, s1.loss_bbox: 0.0895, s2.loss_cls: 0.0298, s2.acc: 95.8925, s2.loss_bbox: 0.0672, loss: 0.4658
# 2023-02-01 19:06:21,004 - mmdet - INFO - Epoch [16][3100/4937]	lr: 2.000e-04, eta: 2:33:21, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0113, loss_rpn_bbox: 0.0115, s0.loss_cls: 0.1226, s0.acc: 95.5820, s0.loss_bbox: 0.0729, s1.loss_cls: 0.0530, s1.acc: 96.1664, s1.loss_bbox: 0.0920, s2.loss_cls: 0.0268, s2.acc: 96.1602, s2.loss_bbox: 0.0666, loss: 0.4567
# 2023-02-01 19:06:41,694 - mmdet - INFO - Epoch [16][3150/4937]	lr: 2.000e-04, eta: 2:33:00, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0130, loss_rpn_bbox: 0.0141, s0.loss_cls: 0.1308, s0.acc: 95.3516, s0.loss_bbox: 0.0762, s1.loss_cls: 0.0531, s1.acc: 96.1925, s1.loss_bbox: 0.0963, s2.loss_cls: 0.0280, s2.acc: 95.8788, s2.loss_bbox: 0.0714, loss: 0.4829
# 2023-02-01 19:07:02,370 - mmdet - INFO - Epoch [16][3200/4937]	lr: 2.000e-04, eta: 2:32:38, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0078, loss_rpn_bbox: 0.0110, s0.loss_cls: 0.1126, s0.acc: 95.8750, s0.loss_bbox: 0.0678, s1.loss_cls: 0.0466, s1.acc: 96.7241, s1.loss_bbox: 0.0867, s2.loss_cls: 0.0246, s2.acc: 96.5364, s2.loss_bbox: 0.0660, loss: 0.4232
# 2023-02-01 19:07:23,053 - mmdet - INFO - Epoch [16][3250/4937]	lr: 2.000e-04, eta: 2:32:17, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0093, loss_rpn_bbox: 0.0127, s0.loss_cls: 0.1236, s0.acc: 95.6680, s0.loss_bbox: 0.0663, s1.loss_cls: 0.0510, s1.acc: 96.3475, s1.loss_bbox: 0.0849, s2.loss_cls: 0.0269, s2.acc: 96.1981, s2.loss_bbox: 0.0610, loss: 0.4356
# 2023-02-01 19:07:43,777 - mmdet - INFO - Epoch [16][3300/4937]	lr: 2.000e-04, eta: 2:31:55, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0128, loss_rpn_bbox: 0.0162, s0.loss_cls: 0.1320, s0.acc: 95.2871, s0.loss_bbox: 0.0761, s1.loss_cls: 0.0543, s1.acc: 96.0395, s1.loss_bbox: 0.0915, s2.loss_cls: 0.0288, s2.acc: 95.6437, s2.loss_bbox: 0.0613, loss: 0.4730
# 2023-02-01 19:08:04,429 - mmdet - INFO - Epoch [16][3350/4937]	lr: 2.000e-04, eta: 2:31:34, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0100, loss_rpn_bbox: 0.0117, s0.loss_cls: 0.1207, s0.acc: 95.7148, s0.loss_bbox: 0.0694, s1.loss_cls: 0.0503, s1.acc: 96.6030, s1.loss_bbox: 0.0883, s2.loss_cls: 0.0262, s2.acc: 96.1830, s2.loss_bbox: 0.0668, loss: 0.4435
# 2023-02-01 19:08:25,154 - mmdet - INFO - Epoch [16][3400/4937]	lr: 2.000e-04, eta: 2:31:12, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0078, loss_rpn_bbox: 0.0121, s0.loss_cls: 0.1010, s0.acc: 96.2207, s0.loss_bbox: 0.0601, s1.loss_cls: 0.0427, s1.acc: 96.8057, s1.loss_bbox: 0.0831, s2.loss_cls: 0.0240, s2.acc: 96.3357, s2.loss_bbox: 0.0660, loss: 0.3969
# 2023-02-01 19:08:45,839 - mmdet - INFO - Epoch [16][3450/4937]	lr: 2.000e-04, eta: 2:30:51, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0157, loss_rpn_bbox: 0.0135, s0.loss_cls: 0.1287, s0.acc: 95.5469, s0.loss_bbox: 0.0718, s1.loss_cls: 0.0553, s1.acc: 96.2088, s1.loss_bbox: 0.0899, s2.loss_cls: 0.0286, s2.acc: 95.8544, s2.loss_bbox: 0.0658, loss: 0.4693
# 2023-02-01 19:09:06,517 - mmdet - INFO - Epoch [16][3500/4937]	lr: 2.000e-04, eta: 2:30:30, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0093, loss_rpn_bbox: 0.0122, s0.loss_cls: 0.1251, s0.acc: 95.5410, s0.loss_bbox: 0.0731, s1.loss_cls: 0.0554, s1.acc: 95.8253, s1.loss_bbox: 0.0870, s2.loss_cls: 0.0289, s2.acc: 95.7943, s2.loss_bbox: 0.0627, loss: 0.4536
# 2023-02-01 19:09:27,208 - mmdet - INFO - Epoch [16][3550/4937]	lr: 2.000e-04, eta: 2:30:08, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0111, loss_rpn_bbox: 0.0137, s0.loss_cls: 0.1233, s0.acc: 95.5820, s0.loss_bbox: 0.0735, s1.loss_cls: 0.0506, s1.acc: 96.2207, s1.loss_bbox: 0.0944, s2.loss_cls: 0.0258, s2.acc: 96.2331, s2.loss_bbox: 0.0715, loss: 0.4640
# 2023-02-01 19:09:47,873 - mmdet - INFO - Epoch [16][3600/4937]	lr: 2.000e-04, eta: 2:29:47, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0079, loss_rpn_bbox: 0.0119, s0.loss_cls: 0.1103, s0.acc: 95.8652, s0.loss_bbox: 0.0685, s1.loss_cls: 0.0453, s1.acc: 96.6602, s1.loss_bbox: 0.0901, s2.loss_cls: 0.0239, s2.acc: 96.4455, s2.loss_bbox: 0.0662, loss: 0.4242
# 2023-02-01 19:10:08,574 - mmdet - INFO - Epoch [16][3650/4937]	lr: 2.000e-04, eta: 2:29:25, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0099, loss_rpn_bbox: 0.0146, s0.loss_cls: 0.1190, s0.acc: 95.7051, s0.loss_bbox: 0.0710, s1.loss_cls: 0.0483, s1.acc: 96.5664, s1.loss_bbox: 0.0903, s2.loss_cls: 0.0254, s2.acc: 96.4238, s2.loss_bbox: 0.0654, loss: 0.4439
# 2023-02-01 19:10:29,218 - mmdet - INFO - Epoch [16][3700/4937]	lr: 2.000e-04, eta: 2:29:04, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0129, loss_rpn_bbox: 0.0112, s0.loss_cls: 0.1132, s0.acc: 96.1113, s0.loss_bbox: 0.0627, s1.loss_cls: 0.0462, s1.acc: 96.9671, s1.loss_bbox: 0.0814, s2.loss_cls: 0.0251, s2.acc: 96.7415, s2.loss_bbox: 0.0600, loss: 0.4127
# 2023-02-01 19:10:49,945 - mmdet - INFO - Epoch [16][3750/4937]	lr: 2.000e-04, eta: 2:28:42, time: 0.415, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0126, s0.loss_cls: 0.1209, s0.acc: 95.7324, s0.loss_bbox: 0.0743, s1.loss_cls: 0.0508, s1.acc: 96.5233, s1.loss_bbox: 0.0964, s2.loss_cls: 0.0262, s2.acc: 96.1774, s2.loss_bbox: 0.0690, loss: 0.4618
# 2023-02-01 19:11:10,602 - mmdet - INFO - Epoch [16][3800/4937]	lr: 2.000e-04, eta: 2:28:21, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0125, loss_rpn_bbox: 0.0130, s0.loss_cls: 0.1232, s0.acc: 95.5410, s0.loss_bbox: 0.0750, s1.loss_cls: 0.0504, s1.acc: 96.4527, s1.loss_bbox: 0.0919, s2.loss_cls: 0.0258, s2.acc: 96.1561, s2.loss_bbox: 0.0649, loss: 0.4569
# 2023-02-01 19:11:31,271 - mmdet - INFO - Epoch [16][3850/4937]	lr: 2.000e-04, eta: 2:27:59, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0144, s0.loss_cls: 0.1332, s0.acc: 95.3398, s0.loss_bbox: 0.0755, s1.loss_cls: 0.0552, s1.acc: 96.0345, s1.loss_bbox: 0.0959, s2.loss_cls: 0.0306, s2.acc: 95.4918, s2.loss_bbox: 0.0685, loss: 0.4849
# 2023-02-01 19:11:51,801 - mmdet - INFO - Epoch [16][3900/4937]	lr: 2.000e-04, eta: 2:27:38, time: 0.411, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0088, loss_rpn_bbox: 0.0131, s0.loss_cls: 0.1182, s0.acc: 95.7793, s0.loss_bbox: 0.0646, s1.loss_cls: 0.0494, s1.acc: 96.4530, s1.loss_bbox: 0.0832, s2.loss_cls: 0.0257, s2.acc: 96.2347, s2.loss_bbox: 0.0615, loss: 0.4246
# 2023-02-01 19:12:12,478 - mmdet - INFO - Epoch [16][3950/4937]	lr: 2.000e-04, eta: 2:27:16, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0120, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1137, s0.acc: 95.8672, s0.loss_bbox: 0.0657, s1.loss_cls: 0.0480, s1.acc: 96.5224, s1.loss_bbox: 0.0869, s2.loss_cls: 0.0259, s2.acc: 96.2032, s2.loss_bbox: 0.0627, loss: 0.4273
# 2023-02-01 19:12:33,166 - mmdet - INFO - Epoch [16][4000/4937]	lr: 2.000e-04, eta: 2:26:55, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0122, loss_rpn_bbox: 0.0143, s0.loss_cls: 0.1261, s0.acc: 95.4902, s0.loss_bbox: 0.0824, s1.loss_cls: 0.0524, s1.acc: 96.3106, s1.loss_bbox: 0.1006, s2.loss_cls: 0.0274, s2.acc: 96.1010, s2.loss_bbox: 0.0708, loss: 0.4862
# 2023-02-01 19:12:53,811 - mmdet - INFO - Epoch [16][4050/4937]	lr: 2.000e-04, eta: 2:26:33, time: 0.413, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0097, loss_rpn_bbox: 0.0115, s0.loss_cls: 0.1219, s0.acc: 95.5762, s0.loss_bbox: 0.0734, s1.loss_cls: 0.0520, s1.acc: 96.3779, s1.loss_bbox: 0.0991, s2.loss_cls: 0.0286, s2.acc: 95.8850, s2.loss_bbox: 0.0721, loss: 0.4683
# 2023-02-01 19:13:14,496 - mmdet - INFO - Epoch [16][4100/4937]	lr: 2.000e-04, eta: 2:26:12, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0115, loss_rpn_bbox: 0.0097, s0.loss_cls: 0.1134, s0.acc: 95.9258, s0.loss_bbox: 0.0671, s1.loss_cls: 0.0471, s1.acc: 96.7124, s1.loss_bbox: 0.0887, s2.loss_cls: 0.0256, s2.acc: 96.3505, s2.loss_bbox: 0.0659, loss: 0.4289
# 2023-02-01 19:13:35,178 - mmdet - INFO - Epoch [16][4150/4937]	lr: 2.000e-04, eta: 2:25:50, time: 0.414, data_time: 0.004, memory: 5518, loss_rpn_cls: 0.0083, loss_rpn_bbox: 0.0115, s0.loss_cls: 0.1200, s0.acc: 95.7246, s0.loss_bbox: 0.0698, s1.loss_cls: 0.0486, s1.acc: 96.5611, s1.loss_bbox: 0.0897, s2.loss_cls: 0.0254, s2.acc: 96.3004, s2.loss_bbox: 0.0697, loss: 0.4430

# %% [markdown]
# 结果：[0.186,0.195,0.206,0.239,0.245,0.249,0.251,0.248,0.294,0.289,0.290,0.289]
