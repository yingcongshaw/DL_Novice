# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
# Out:
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
# 指定模型及其对应的训练模型
config_file = './work_dirs/faster_rcnn_r50_fpn_1x_didi/faster_rcnn_r50_fpn_1x_didi.py'
checkpoint_file = './work_dirs/faster_rcnn_r50_fpn_1x_didi/latest.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./work_dirs/faster_rcnn_r50_fpn_1x_didi/latest.pth

# %%
# test a single image
img = './dataset_release/train/0.jpg'
result = inference_detector(model, img)

# %%
# show the results
show_result_pyplot(model, img, result)

# %%
# 指定模型及其对应的训练模型
config_file = './configs/cascade_rcnn/cascade_rcnn_r50_fpn_1x_didi.py'
checkpoint_file = './work_dirs/cascade_rcnn_r50_fpn_1x_didi/latest.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./work_dirs/cascade_rcnn_r50_fpn_1x_didi/latest.pth

# %%
# test a single image
img = './dataset_release/train/0.jpg'
result = inference_detector(model, img)
# Out:
# /home/shaw/work/DL/hw5/mmdetection/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %%
# show the results
show_result_pyplot(model, img, result)

# %%
# !python tools/test.py ./work_dirs/cascade_rcnn_r50_fpn_1x_didi/cascade_rcnn_r50_fpn_1x_didi.py \
    ./work_dirs/cascade_rcnn_r50_fpn_1x_didi/latest.pth \
    --format-only --eval-options 'jsonfile_prefix=./text_results'
# Out:
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# ...
