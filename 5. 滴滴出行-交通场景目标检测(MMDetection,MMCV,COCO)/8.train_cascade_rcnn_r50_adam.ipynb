# %% [markdown]
# ### cascade_r50_adam

# %%
import glob
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 默认

# %%
# !python mmdetection/tools/train.py mmdetection/configs/cascade_rcnn/cascade_rcnn_r50_fpn_1x_didi.py
# Out:
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /home/shaw/anaconda3/envs/hw5/lib/python3.9/site-packages/mmdet/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2023-02-02 07:51:13,617 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.9.15 (main, Nov 24 2022, 14:31:59) [GCC 11.2.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3070
# CUDA_HOME: /usr/local/cuda-11.7
# NVCC: Cuda compilation tools, release 11.7, V11.7.99
# GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04) 11.3.0
# PyTorch: 1.13.1+cu117-with-pypi-cudnn
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.14.1+cu117
# OpenCV: 4.7.0
# MMCV: 1.7.1
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.7
# MMDetection: 2.27.0+unknown
# ------------------------------------------------------------
#
# 2023-02-02 07:51:14,119 - mmdet - INFO - Distributed training: False
# 2023-02-02 07:51:14,565 - mmdet - INFO - Config:
# model = dict(
#     type='CascadeRCNN',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(
#             type='SmoothL1Loss', beta=0.1111111111111111, loss_weight=1.0)),
#     roi_head=dict(
#         type='CascadeRoIHead',
#         num_stages=3,
#         stage_loss_weights=[1, 0.5, 0.25],
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=[
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.1, 0.1, 0.2, 0.2]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.05, 0.05, 0.1, 0.1]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=12,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.033, 0.033, 0.067, 0.067]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0))
#         ]),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=0,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=2000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.5,
#                     neg_iou_thr=0.5,
#                     min_pos_iou=0.5,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.6,
#                     neg_iou_thr=0.6,
#                     min_pos_iou=0.6,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.7,
#                     neg_iou_thr=0.7,
#                     min_pos_iou=0.7,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False)
#         ]),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = '/home/shaw/work/DL/hw5/mmdetection/dataset_release/'
# classes = ('car', 'van', 'bus', 'truck', 'person', 'bicycle', 'motorcycle',
#            'open-tricycle', 'closed-tricycle', 'forklift', 'large-block',
#            'small-block')
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file=
#         '/home/shaw/work/DL/hw5/mmdetection/dataset_release/train.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/train/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file='/home/shaw/work/DL/hw5/mmdetection/dataset_release/val.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/val/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CocoDataset',
#         classes=('car', 'van', 'bus', 'truck', 'person', 'bicycle',
#                  'motorcycle', 'open-tricycle', 'closed-tricycle', 'forklift',
#                  'large-block', 'small-block'),
#         ann_file='/home/shaw/work/DL/hw5/mmdetection/dataset_release/test.json',
#         img_prefix='/home/shaw/work/DL/hw5/mmdetection/dataset_release/test/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=1, metric='bbox')
# optimizer = dict(type='Adam', lr=0.0001, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=200,
#     warmup_ratio=0.001,
#     step=[4, 8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(interval=50, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=8)
# work_dir = './work_dirs/cascade_rcnn_r50_fpn_1x_didi'
# auto_resume = False
# gpu_ids = [0]
#
# 2023-02-02 07:51:14,566 - mmdet - INFO - Set random seed to 1592418531, deterministic: False
# 2023-02-02 07:51:14,924 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2023-02-02 07:51:14,924 - mmcv - INFO - load model from: torchvision://resnet50
# 2023-02-02 07:51:14,924 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2023-02-02 07:51:14,984 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2023-02-02 07:51:14,998 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2023-02-02 07:51:15,016 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2023-02-02 07:51:15,020 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-02 07:51:15,086 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-02 07:51:15,153 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,230 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,231 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,232 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,233 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,234 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 256, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# roi_head.bbox_head.0.fc_cls.weight - torch.Size([13, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,235 - mmcv - INFO -
# roi_head.bbox_head.0.fc_cls.bias - torch.Size([13]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.0.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.fc_cls.weight - torch.Size([13, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.fc_cls.bias - torch.Size([13]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.1.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.fc_cls.weight - torch.Size([13, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.fc_cls.bias - torch.Size([13]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-02 07:51:15,236 - mmcv - INFO -
# roi_head.bbox_head.2.shared_fcs.1.weight - torch.Size([1024, 1024]):
# ...
# 2023-02-02 13:17:16,290 - mmdet - INFO - Epoch [12][3100/4937]	lr: 1.000e-07, eta: 0:09:54, time: 0.334, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0114, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1164, s0.acc: 95.8105, s0.loss_bbox: 0.0698, s1.loss_cls: 0.0497, s1.acc: 96.5215, s1.loss_bbox: 0.0913, s2.loss_cls: 0.0263, s2.acc: 96.2890, s2.loss_bbox: 0.0680, loss: 0.4452
# 2023-02-02 13:17:33,083 - mmdet - INFO - Epoch [12][3150/4937]	lr: 1.000e-07, eta: 0:09:38, time: 0.336, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0125, loss_rpn_bbox: 0.0136, s0.loss_cls: 0.1307, s0.acc: 95.2617, s0.loss_bbox: 0.0738, s1.loss_cls: 0.0576, s1.acc: 95.9608, s1.loss_bbox: 0.0939, s2.loss_cls: 0.0296, s2.acc: 95.5500, s2.loss_bbox: 0.0685, loss: 0.4802
# 2023-02-02 13:17:49,974 - mmdet - INFO - Epoch [12][3200/4937]	lr: 1.000e-07, eta: 0:09:22, time: 0.338, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0112, loss_rpn_bbox: 0.0117, s0.loss_cls: 0.1174, s0.acc: 95.8848, s0.loss_bbox: 0.0694, s1.loss_cls: 0.0516, s1.acc: 96.5245, s1.loss_bbox: 0.0942, s2.loss_cls: 0.0279, s2.acc: 96.1987, s2.loss_bbox: 0.0703, loss: 0.4537
# 2023-02-02 13:18:06,869 - mmdet - INFO - Epoch [12][3250/4937]	lr: 1.000e-07, eta: 0:09:05, time: 0.338, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0145, loss_rpn_bbox: 0.0142, s0.loss_cls: 0.1416, s0.acc: 94.8672, s0.loss_bbox: 0.0769, s1.loss_cls: 0.0621, s1.acc: 95.5700, s1.loss_bbox: 0.0971, s2.loss_cls: 0.0323, s2.acc: 95.3361, s2.loss_bbox: 0.0714, loss: 0.5101
# 2023-02-02 13:18:23,692 - mmdet - INFO - Epoch [12][3300/4937]	lr: 1.000e-07, eta: 0:08:49, time: 0.336, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0121, loss_rpn_bbox: 0.0143, s0.loss_cls: 0.1412, s0.acc: 95.2715, s0.loss_bbox: 0.0792, s1.loss_cls: 0.0602, s1.acc: 96.0747, s1.loss_bbox: 0.1041, s2.loss_cls: 0.0317, s2.acc: 95.4496, s2.loss_bbox: 0.0735, loss: 0.5164
# 2023-02-02 13:18:40,477 - mmdet - INFO - Epoch [12][3350/4937]	lr: 1.000e-07, eta: 0:08:33, time: 0.336, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0109, loss_rpn_bbox: 0.0115, s0.loss_cls: 0.1084, s0.acc: 96.1777, s0.loss_bbox: 0.0629, s1.loss_cls: 0.0489, s1.acc: 96.5891, s1.loss_bbox: 0.0804, s2.loss_cls: 0.0255, s2.acc: 96.3264, s2.loss_bbox: 0.0575, loss: 0.4059
# 2023-02-02 13:18:57,242 - mmdet - INFO - Epoch [12][3400/4937]	lr: 1.000e-07, eta: 0:08:17, time: 0.335, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0101, loss_rpn_bbox: 0.0139, s0.loss_cls: 0.1416, s0.acc: 95.1387, s0.loss_bbox: 0.0780, s1.loss_cls: 0.0612, s1.acc: 95.7803, s1.loss_bbox: 0.0944, s2.loss_cls: 0.0299, s2.acc: 95.9008, s2.loss_bbox: 0.0675, loss: 0.4966
# 2023-02-02 13:19:13,888 - mmdet - INFO - Epoch [12][3450/4937]	lr: 1.000e-07, eta: 0:08:01, time: 0.333, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0096, loss_rpn_bbox: 0.0118, s0.loss_cls: 0.1219, s0.acc: 95.6152, s0.loss_bbox: 0.0701, s1.loss_cls: 0.0526, s1.acc: 96.3949, s1.loss_bbox: 0.0942, s2.loss_cls: 0.0275, s2.acc: 95.9561, s2.loss_bbox: 0.0700, loss: 0.4578
# 2023-02-02 13:19:30,751 - mmdet - INFO - Epoch [12][3500/4937]	lr: 1.000e-07, eta: 0:07:45, time: 0.337, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0104, loss_rpn_bbox: 0.0136, s0.loss_cls: 0.1293, s0.acc: 95.2539, s0.loss_bbox: 0.0797, s1.loss_cls: 0.0525, s1.acc: 96.2443, s1.loss_bbox: 0.0998, s2.loss_cls: 0.0271, s2.acc: 96.0246, s2.loss_bbox: 0.0736, loss: 0.4860
# 2023-02-02 13:19:47,409 - mmdet - INFO - Epoch [12][3550/4937]	lr: 1.000e-07, eta: 0:07:28, time: 0.333, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0109, loss_rpn_bbox: 0.0149, s0.loss_cls: 0.1344, s0.acc: 95.2109, s0.loss_bbox: 0.0803, s1.loss_cls: 0.0591, s1.acc: 95.7786, s1.loss_bbox: 0.1002, s2.loss_cls: 0.0316, s2.acc: 95.3533, s2.loss_bbox: 0.0709, loss: 0.5023
# 2023-02-02 13:20:03,961 - mmdet - INFO - Epoch [12][3600/4937]	lr: 1.000e-07, eta: 0:07:12, time: 0.331, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0115, loss_rpn_bbox: 0.0138, s0.loss_cls: 0.1236, s0.acc: 95.7266, s0.loss_bbox: 0.0697, s1.loss_cls: 0.0538, s1.acc: 96.4923, s1.loss_bbox: 0.0910, s2.loss_cls: 0.0281, s2.acc: 96.2942, s2.loss_bbox: 0.0681, loss: 0.4597
# 2023-02-02 13:20:20,521 - mmdet - INFO - Epoch [12][3650/4937]	lr: 1.000e-07, eta: 0:06:56, time: 0.331, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0147, loss_rpn_bbox: 0.0127, s0.loss_cls: 0.1345, s0.acc: 95.2402, s0.loss_bbox: 0.0782, s1.loss_cls: 0.0592, s1.acc: 95.8365, s1.loss_bbox: 0.1006, s2.loss_cls: 0.0304, s2.acc: 95.6101, s2.loss_bbox: 0.0727, loss: 0.5031
# 2023-02-02 13:20:37,115 - mmdet - INFO - Epoch [12][3700/4937]	lr: 1.000e-07, eta: 0:06:40, time: 0.332, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0110, loss_rpn_bbox: 0.0117, s0.loss_cls: 0.1209, s0.acc: 95.5918, s0.loss_bbox: 0.0717, s1.loss_cls: 0.0503, s1.acc: 96.4569, s1.loss_bbox: 0.0956, s2.loss_cls: 0.0253, s2.acc: 96.3055, s2.loss_bbox: 0.0689, loss: 0.4554
# 2023-02-02 13:20:53,728 - mmdet - INFO - Epoch [12][3750/4937]	lr: 1.000e-07, eta: 0:06:24, time: 0.332, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0097, loss_rpn_bbox: 0.0092, s0.loss_cls: 0.1063, s0.acc: 96.2832, s0.loss_bbox: 0.0605, s1.loss_cls: 0.0462, s1.acc: 96.7535, s1.loss_bbox: 0.0820, s2.loss_cls: 0.0240, s2.acc: 96.5720, s2.loss_bbox: 0.0609, loss: 0.3989
# 2023-02-02 13:21:10,303 - mmdet - INFO - Epoch [12][3800/4937]	lr: 1.000e-07, eta: 0:06:08, time: 0.332, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0133, loss_rpn_bbox: 0.0116, s0.loss_cls: 0.1266, s0.acc: 95.4082, s0.loss_bbox: 0.0673, s1.loss_cls: 0.0552, s1.acc: 96.0269, s1.loss_bbox: 0.0910, s2.loss_cls: 0.0277, s2.acc: 96.0976, s2.loss_bbox: 0.0686, loss: 0.4613
# 2023-02-02 13:21:27,003 - mmdet - INFO - Epoch [12][3850/4937]	lr: 1.000e-07, eta: 0:05:51, time: 0.334, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0086, loss_rpn_bbox: 0.0121, s0.loss_cls: 0.1237, s0.acc: 95.5977, s0.loss_bbox: 0.0757, s1.loss_cls: 0.0549, s1.acc: 96.0625, s1.loss_bbox: 0.0974, s2.loss_cls: 0.0284, s2.acc: 95.5763, s2.loss_bbox: 0.0708, loss: 0.4716
# 2023-02-02 13:21:43,806 - mmdet - INFO - Epoch [12][3900/4937]	lr: 1.000e-07, eta: 0:05:35, time: 0.336, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0143, loss_rpn_bbox: 0.0152, s0.loss_cls: 0.1407, s0.acc: 95.0762, s0.loss_bbox: 0.0798, s1.loss_cls: 0.0628, s1.acc: 95.6859, s1.loss_bbox: 0.1007, s2.loss_cls: 0.0328, s2.acc: 95.3419, s2.loss_bbox: 0.0707, loss: 0.5172
# 2023-02-02 13:22:00,443 - mmdet - INFO - Epoch [12][3950/4937]	lr: 1.000e-07, eta: 0:05:19, time: 0.333, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0127, loss_rpn_bbox: 0.0154, s0.loss_cls: 0.1300, s0.acc: 95.3438, s0.loss_bbox: 0.0774, s1.loss_cls: 0.0560, s1.acc: 96.2156, s1.loss_bbox: 0.0951, s2.loss_cls: 0.0302, s2.acc: 95.6317, s2.loss_bbox: 0.0663, loss: 0.4832
# 2023-02-02 13:22:17,054 - mmdet - INFO - Epoch [12][4000/4937]	lr: 1.000e-07, eta: 0:05:03, time: 0.332, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0104, loss_rpn_bbox: 0.0095, s0.loss_cls: 0.1111, s0.acc: 96.1836, s0.loss_bbox: 0.0638, s1.loss_cls: 0.0467, s1.acc: 96.8073, s1.loss_bbox: 0.0812, s2.loss_cls: 0.0234, s2.acc: 96.6673, s2.loss_bbox: 0.0581, loss: 0.4042
# 2023-02-02 13:22:33,775 - mmdet - INFO - Epoch [12][4050/4937]	lr: 1.000e-07, eta: 0:04:47, time: 0.334, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0124, loss_rpn_bbox: 0.0145, s0.loss_cls: 0.1433, s0.acc: 94.9395, s0.loss_bbox: 0.0780, s1.loss_cls: 0.0639, s1.acc: 95.6936, s1.loss_bbox: 0.1033, s2.loss_cls: 0.0341, s2.acc: 95.2281, s2.loss_bbox: 0.0727, loss: 0.5222
# 2023-02-02 13:22:50,432 - mmdet - INFO - Epoch [12][4100/4937]	lr: 1.000e-07, eta: 0:04:30, time: 0.333, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0127, loss_rpn_bbox: 0.0123, s0.loss_cls: 0.1254, s0.acc: 95.6289, s0.loss_bbox: 0.0721, s1.loss_cls: 0.0540, s1.acc: 96.2019, s1.loss_bbox: 0.0950, s2.loss_cls: 0.0287, s2.acc: 95.8807, s2.loss_bbox: 0.0729, loss: 0.4732
# 2023-02-02 13:23:06,931 - mmdet - INFO - Epoch [12][4150/4937]	lr: 1.000e-07, eta: 0:04:14, time: 0.330, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0107, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1273, s0.acc: 95.3262, s0.loss_bbox: 0.0761, s1.loss_cls: 0.0548, s1.acc: 96.0760, s1.loss_bbox: 0.0949, s2.loss_cls: 0.0290, s2.acc: 95.6987, s2.loss_bbox: 0.0672, loss: 0.4724
# 2023-02-02 13:23:23,609 - mmdet - INFO - Epoch [12][4200/4937]	lr: 1.000e-07, eta: 0:03:58, time: 0.334, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0110, s0.loss_cls: 0.1279, s0.acc: 95.6562, s0.loss_bbox: 0.0642, s1.loss_cls: 0.0546, s1.acc: 96.4230, s1.loss_bbox: 0.0878, s2.loss_cls: 0.0281, s2.acc: 96.4310, s2.loss_bbox: 0.0661, loss: 0.4513
# 2023-02-02 13:23:40,359 - mmdet - INFO - Epoch [12][4250/4937]	lr: 1.000e-07, eta: 0:03:42, time: 0.335, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0148, s0.loss_cls: 0.1292, s0.acc: 95.2891, s0.loss_bbox: 0.0812, s1.loss_cls: 0.0594, s1.acc: 95.7153, s1.loss_bbox: 0.1041, s2.loss_cls: 0.0337, s2.acc: 95.0807, s2.loss_bbox: 0.0729, loss: 0.5071
# 2023-02-02 13:23:56,131 - mmdet - INFO - Epoch [12][4300/4937]	lr: 1.000e-07, eta: 0:03:26, time: 0.315, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0116, loss_rpn_bbox: 0.0123, s0.loss_cls: 0.1260, s0.acc: 95.7012, s0.loss_bbox: 0.0726, s1.loss_cls: 0.0568, s1.acc: 96.0938, s1.loss_bbox: 0.0932, s2.loss_cls: 0.0293, s2.acc: 95.8951, s2.loss_bbox: 0.0654, loss: 0.4672
# 2023-02-02 13:24:11,889 - mmdet - INFO - Epoch [12][4350/4937]	lr: 1.000e-07, eta: 0:03:10, time: 0.315, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0139, loss_rpn_bbox: 0.0137, s0.loss_cls: 0.1308, s0.acc: 95.3672, s0.loss_bbox: 0.0725, s1.loss_cls: 0.0576, s1.acc: 95.9417, s1.loss_bbox: 0.0950, s2.loss_cls: 0.0296, s2.acc: 95.6001, s2.loss_bbox: 0.0692, loss: 0.4823
# 2023-02-02 13:24:27,491 - mmdet - INFO - Epoch [12][4400/4937]	lr: 1.000e-07, eta: 0:02:53, time: 0.312, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0156, loss_rpn_bbox: 0.0121, s0.loss_cls: 0.1154, s0.acc: 95.9824, s0.loss_bbox: 0.0631, s1.loss_cls: 0.0522, s1.acc: 96.4038, s1.loss_bbox: 0.0844, s2.loss_cls: 0.0281, s2.acc: 96.1629, s2.loss_bbox: 0.0658, loss: 0.4366
# 2023-02-02 13:24:43,138 - mmdet - INFO - Epoch [12][4450/4937]	lr: 1.000e-07, eta: 0:02:37, time: 0.313, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0134, loss_rpn_bbox: 0.0125, s0.loss_cls: 0.1160, s0.acc: 95.7930, s0.loss_bbox: 0.0697, s1.loss_cls: 0.0493, s1.acc: 96.5054, s1.loss_bbox: 0.0900, s2.loss_cls: 0.0253, s2.acc: 96.4064, s2.loss_bbox: 0.0685, loss: 0.4446
# 2023-02-02 13:24:58,882 - mmdet - INFO - Epoch [12][4500/4937]	lr: 1.000e-07, eta: 0:02:21, time: 0.315, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0120, loss_rpn_bbox: 0.0148, s0.loss_cls: 0.1296, s0.acc: 95.4199, s0.loss_bbox: 0.0797, s1.loss_cls: 0.0566, s1.acc: 96.0154, s1.loss_bbox: 0.0993, s2.loss_cls: 0.0295, s2.acc: 95.7809, s2.loss_bbox: 0.0717, loss: 0.4931
# 2023-02-02 13:25:14,582 - mmdet - INFO - Epoch [12][4550/4937]	lr: 1.000e-07, eta: 0:02:05, time: 0.314, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0098, loss_rpn_bbox: 0.0121, s0.loss_cls: 0.1197, s0.acc: 95.6543, s0.loss_bbox: 0.0681, s1.loss_cls: 0.0542, s1.acc: 96.1293, s1.loss_bbox: 0.0943, s2.loss_cls: 0.0273, s2.acc: 95.9037, s2.loss_bbox: 0.0690, loss: 0.4545
# 2023-02-02 13:25:30,244 - mmdet - INFO - Epoch [12][4600/4937]	lr: 1.000e-07, eta: 0:01:49, time: 0.313, data_time: 0.004, memory: 4234, loss_rpn_cls: 0.0084, loss_rpn_bbox: 0.0109, s0.loss_cls: 0.1141, s0.acc: 95.9922, s0.loss_bbox: 0.0632, s1.loss_cls: 0.0508, s1.acc: 96.5064, s1.loss_bbox: 0.0816, s2.loss_cls: 0.0265, s2.acc: 96.2163, s2.loss_bbox: 0.0622, loss: 0.4177
# 2023-02-02 13:25:46,445 - mmdet - INFO - Epoch [12][4650/4937]	lr: 1.000e-07, eta: 0:01:32, time: 0.324, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0144, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1191, s0.acc: 95.8223, s0.loss_bbox: 0.0707, s1.loss_cls: 0.0510, s1.acc: 96.4057, s1.loss_bbox: 0.0940, s2.loss_cls: 0.0262, s2.acc: 96.3340, s2.loss_bbox: 0.0706, loss: 0.4584
# 2023-02-02 13:26:03,052 - mmdet - INFO - Epoch [12][4700/4937]	lr: 1.000e-07, eta: 0:01:16, time: 0.332, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0117, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1210, s0.acc: 95.4805, s0.loss_bbox: 0.0662, s1.loss_cls: 0.0527, s1.acc: 96.1761, s1.loss_bbox: 0.0859, s2.loss_cls: 0.0271, s2.acc: 96.0866, s2.loss_bbox: 0.0647, loss: 0.4417
# 2023-02-02 13:26:19,328 - mmdet - INFO - Epoch [12][4750/4937]	lr: 1.000e-07, eta: 0:01:00, time: 0.326, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0121, loss_rpn_bbox: 0.0126, s0.loss_cls: 0.1267, s0.acc: 95.4668, s0.loss_bbox: 0.0794, s1.loss_cls: 0.0542, s1.acc: 96.1546, s1.loss_bbox: 0.0964, s2.loss_cls: 0.0292, s2.acc: 96.1442, s2.loss_bbox: 0.0697, loss: 0.4803
# 2023-02-02 13:26:35,889 - mmdet - INFO - Epoch [12][4800/4937]	lr: 1.000e-07, eta: 0:00:44, time: 0.331, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0137, loss_rpn_bbox: 0.0144, s0.loss_cls: 0.1343, s0.acc: 95.1875, s0.loss_bbox: 0.0771, s1.loss_cls: 0.0592, s1.acc: 95.8091, s1.loss_bbox: 0.0979, s2.loss_cls: 0.0311, s2.acc: 95.5249, s2.loss_bbox: 0.0703, loss: 0.4981
# 2023-02-02 13:26:52,422 - mmdet - INFO - Epoch [12][4850/4937]	lr: 1.000e-07, eta: 0:00:28, time: 0.331, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0133, loss_rpn_bbox: 0.0124, s0.loss_cls: 0.1140, s0.acc: 96.0293, s0.loss_bbox: 0.0671, s1.loss_cls: 0.0489, s1.acc: 96.6278, s1.loss_bbox: 0.0891, s2.loss_cls: 0.0249, s2.acc: 96.3905, s2.loss_bbox: 0.0665, loss: 0.4362
# 2023-02-02 13:27:08,966 - mmdet - INFO - Epoch [12][4900/4937]	lr: 1.000e-07, eta: 0:00:11, time: 0.331, data_time: 0.005, memory: 4234, loss_rpn_cls: 0.0092, loss_rpn_bbox: 0.0129, s0.loss_cls: 0.1302, s0.acc: 95.2891, s0.loss_bbox: 0.0725, s1.loss_cls: 0.0555, s1.acc: 96.0466, s1.loss_bbox: 0.0914, s2.loss_cls: 0.0280, s2.acc: 95.8815, s2.loss_bbox: 0.0665, loss: 0.4663
# 2023-02-02 13:27:21,180 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1000/1000, 14.6 task/s, elapsed: 68s, ETA:     0s2023-02-02 13:28:31,275 - mmdet - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.04s).
# Accumulating evaluation results...
# DONE (t=0.45s).
# 2023-02-02 13:28:33,828 - mmdet - INFO -
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.463
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.463
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.630
#
# 2023-02-02 13:28:33,854 - mmdet - INFO - Exp name: cascade_rcnn_r50_fpn_1x_didi.py
# 2023-02-02 13:28:33,855 - mmdet - INFO - Epoch(val) [12][1000]	bbox_mAP: 0.2880, bbox_mAP_50: 0.4630, bbox_mAP_75: 0.2910, bbox_mAP_s: 0.1150, bbox_mAP_m: 0.3070, bbox_mAP_l: 0.4630, bbox_mAP_copypaste: 0.288 0.463 0.291 0.115 0.307 0.463

# %% [markdown]
# 结果：[0.186,0.195,0.206,0.239,0.245,0.249,0.251,0.248,0.294,0.289,0.290,0.289]
