# %% [markdown]
# ### cascade_rcnn_结果对比

# %%
# import glob
# import json
import numpy as np
# import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 默认

# %%
# 默认 数据来源：1.train_faster_rcnn_r51_epochs20.ipynb
result_default = [0.166,0.197,0.203, 0.219,0.234,0.226,0.206,0.228,0.278,0.28,0.281,0.285]
# 数据来源：参见 6.train_cascade_rcnn_r50.ipynb
result_cascade_r50_sgd_lr02 = [0.1640,0.2120,0.2270,0.2400,0.2590,0.2430,0.2630,0.2460,0.2920,0.2950,0.2960,0.2970]
# 数据来源：参见7 .train_cascade_rcnn_r50_lr002.ipynb
result_cascade_r50_sgd_lr002 = [0.1770,0.2080,0.2380,0.2440,0.2610,0.2630,0.2610,0.2630,0.2650,0.2630,0.2650,0.2640]
# 数据来源：参见 8.train_cascade_rcnn_r50_adam.ipynb
result_cascade_r50_sgd_adam =0.1970,0.2350,0.2590,0.2610,0.2910,0.2860,0.2890,0.2860,0.2890,0.2880,0.2870,0.2880
# 数据来源：参见 9.cascade_rcnn_r101_fpn_1x_didi
result_cascade_r101_sgd_lr02 =[0.186,0.195,0.206,0.239,0.245,0.249,0.251,0.248,0.294,0.289,0.290,0.289]

plt.figure(figsize=(10,6), dpi=100)
plt.rcParams['font.sans-serif']=['SimHei']
plt.plot(range(1,13), result_default, marker='s', label ='default')
plt.plot(range(1,13), result_cascade_r50_sgd_lr02, marker='s', label ='cascade_r50_sgd_lr02')
plt.plot(range(1,13), result_cascade_r50_sgd_lr002, marker='s', label ='cascade_r50_sgd_lr002')
plt.plot(range(1,13), result_cascade_r50_sgd_adam, marker='s', label ='cascade_r101_adam')
plt.plot(range(1,13), result_cascade_r101_sgd_lr02, marker='s', label ='cascade_r101_sgd_lr02')
plt.xlabel('epoch', fontsize=16)
plt.xticks(range(0,13), fontsize=12)
plt.ylabel('mAP', fontsize=16)
plt.yticks(np.arange(150,310,10)/1000,fontsize=12)
plt.legend()
plt.show()
